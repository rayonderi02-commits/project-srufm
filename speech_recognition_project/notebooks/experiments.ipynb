# %% [markdown]
# # Kiswahili ASR — Experiments Notebook
#
# Use this notebook for exploratory analysis, feature visualization, and model experiments.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.preprocessing.noise_reduction import NoiseReducer
from src.preprocessing.silence_removal import SilenceRemover
from src.preprocessing.normalization import AudioNormalizer
from src.features.mfcc_extraction import FeatureExtractor
from src.utils.config import Config

config = Config.load('../config/default.yaml')
print('Config loaded:', config)

# %% [markdown]
# ## 1. Load and Inspect Metadata

# %%
df = pd.read_csv('../data/metadata.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## 2. Accent Distribution

# %%
df['accent_label'].value_counts().plot(kind='bar', title='Accent Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. MFCC Visualization

# %%
# TODO: Load a sample audio and plot its MFCC spectrogram
# import librosa.display
# audio, sr = librosa.load('path/to/sample.wav', sr=16000)
# mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
# librosa.display.specshow(mfcc, x_axis='time')
# plt.colorbar()
# plt.title('MFCC')
# plt.show()
